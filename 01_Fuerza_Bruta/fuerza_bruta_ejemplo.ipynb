# %% [markdown]
# ## Ejemplo 1: Búsqueda Lineal
#
# La forma más simple de búsqueda: revisar cada elemento secuencialmente.

# %%
def busqueda_lineal(lista, objetivo):
    """
    Busca un elemento en una lista.
    Complejidad: O(n)
    """
    for i in range(len(lista)):
        if lista[i] == objetivo:
            return i
    return -1

# Prueba
numeros = [4, 2, 7, 1, 9, 5, 3]
objetivo = 9

resultado = busqueda_lineal(numeros, objetivo)
print(f"Lista: {numeros}")
print(f"Buscando: {objetivo}")
print(f"Encontrado en índice: {resultado}" if resultado != -1 else "No encontrado")

# %% [markdown]
# ## Ejemplo 2: Generación de Subconjuntos
#
# Generar todos los subconjuntos posibles de un conjunto (2ⁿ posibilidades).

# %%
def generar_subconjuntos(conjunto):
    """
    Genera todos los subconjuntos de un conjunto.
    Complejidad: O(2^n)
    """
    n = len(conjunto)
    subconjuntos = []
    
    # Hay 2^n subconjuntos posibles
    for i in range(2**n):
        subconjunto = []
        for j in range(n):
            # Verificar si el j-ésimo bit está activado
            if (i >> j) & 1:
                subconjunto.append(conjunto[j])
        subconjuntos.append(subconjunto)
    
    return subconjuntos

# Prueba
conjunto = [1, 2, 3]
subconjuntos = generar_subconjuntos(conjunto)

print(f"Conjunto: {conjunto}")
print(f"\nTodos los subconjuntos ({len(subconjuntos)} total):")
for sub in subconjuntos:
    print(f"  {sub}")

# %% [markdown]
# ## Ejemplo 3: Problema de la Suma de Subconjunto
#
# Encontrar todos los subconjuntos que suman un valor objetivo.

# %%
def suma_subconjunto(numeros, objetivo):
    """
    Encuentra subconjuntos que suman el objetivo.
    Complejidad: O(2^n)
    """
    n = len(numeros)
    soluciones = []
    
    for i in range(2**n):
        subconjunto = []
        suma = 0
        for j in range(n):
            if (i >> j) & 1:
                subconjunto.append(numeros[j])
                suma += numeros[j]
        
        if suma == objetivo:
            soluciones.append(subconjunto)
    
    return soluciones

# Prueba
numeros = [1, 2, 3, 4, 5]
objetivo = 7

soluciones = suma_subconjunto(numeros, objetivo)

print(f"Números: {numeros}")
print(f"Objetivo: {objetivo}")
print(f"\nSubconjuntos que suman {objetivo}:")
for sol in soluciones:
    print(f"  {sol} → suma = {sum(sol)}")

# %% [markdown]
# ## 🎯 Ejercicio Práctico
#
# Modifica el código anterior para encontrar el subconjunto más grande que suma el objetivo.

# %%
# Tu código aquí
def subconjunto_mas_grande(numeros, objetivo):
    soluciones = suma_subconjunto(numeros, objetivo)
    if not soluciones:
        return None
    return max(soluciones, key=len)

# Prueba tu solución
resultado = subconjunto_mas_grande([1, 2, 3, 4, 5], 7)
print(f"Subconjunto más grande: {resultado}")

# %% [markdown]
# ## 📊 Análisis de Rendimiento
#
# Veamos cómo crece el tiempo con el tamaño del problema.

# %%
import time

def medir_tiempo(n):
    conjunto = list(range(n))
    inicio = time.time()
    subconjuntos = generar_subconjuntos(conjunto)
    fin = time.time()
    return (fin - inicio) * 1000, len(subconjuntos)

print("n\tTiempo (ms)\tSubconjuntos")
print("="*40)
for n in range(5, 16):
    tiempo, count = medir_tiempo(n)
    print(f"{n}\t{tiempo:8.2f}\t{count:10d}")

# %% [markdown]
# ## 🎓 Conclusiones
#
# - ✅ Fuerza bruta es simple de implementar
# - ⚠️ Solo viable para problemas pequeños
# - 🚀 Para problemas grandes, necesitamos estrategias más eficientes
#
# **Siguiente:** [Dividir y Conquistar](../02_Dividir_y_Conquistar/README.md)
